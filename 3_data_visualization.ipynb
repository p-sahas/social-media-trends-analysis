# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# ### 1. Setup and Data Loading

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load processed data
try:
    df = pd.read_csv('data/processed/processed_data.csv')
    print(f"Dataset Shape: {df.shape}")
    display(df.head())
except FileNotFoundError:
    print("Processed data not found. Please run 0_data_preparation.ipynb first.")
# Out:
# Dataset Shape: (5000, 36)
#      Views   Likes  Shares  Comments  Month  DayOfWeek  Is_Weekend  \
# 0  4163464  339431   53135     19346      1          3           0
# 1  4155940  215240   65860     27239      5          4           0
# 2  3666211  327143   39423     36223      1          4           0
# 3   917951  127125   11687     36806     12          0           0
# 4    64866  171361   69581      6376      3          3           0
#
#    Likes_Per_View  Shares_Per_View  Comments_Per_View  ...  \
# 0        0.081526         0.012762           0.004647  ...
# 1        0.051791         0.015847           0.006554  ...
# 2        0.089232         0.010753           0.009880  ...
# 3        0.138488         0.012732           0.040096  ...
# 4        2.641769         1.072688           0.098295  ...
#
#    Content_Type_Tweet  Content_Type_Video  Region_Brazil  Region_Canada  \
# 0               False                True          False          False
# ...

# %% [markdown]
# ### 2. Correlation Analysis

# %%
plt.figure(figsize=(12, 10))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### 3. Distribution of Key Features

# %%
features = ['Views','Likes','Shares','Comments','Engagement_Rate', 'Likes_Per_View', 'Shares_Per_View', 'Comments_Per_View']

for feature in features:
    plt.figure(figsize=(5, 3))
    sns.histplot(df[feature], kde=True, bins=30)
    plt.title(f'Distribution of {feature}')
    plt.savefig(f'figures/dis_plots/dis_of_{feature}.jpg')
    plt.show()

# %% [markdown]
# ### 4. Engagement by Time

# %%
if 'Month' in df.columns:
    plt.figure(figsize=(10, 6))
    sns.barplot(x='Month', y='Engagement_Rate', data=df)
    plt.title('Average Engagement Rate by Month')
    plt.savefig(f'figures/eng_by_time/avg_eng_month.jpg')
    plt.show()

if 'DayOfWeek' in df.columns:
    plt.figure(figsize=(10, 6))
    sns.barplot(x='DayOfWeek', y='Engagement_Rate', data=df)
    plt.title('Average Engagement Rate by Day of Week (0=Mon, 6=Sun)')
    plt.savefig(f'figures/eng_by_time/avg_eng_week.jpg')
    plt.show()
